# %% [markdown]
# # Saúde Bucal - material suplementar

# %% [markdown]
# ## Procedimentos metodológicos
# ---
# A construção do modelo de planejamento da força de trabalho (PDFT) para saúde bucal baseado em necessidades foi elaborado a partir das orientações de Asamani et al. (2021) que sugerem algumas etapas, que serão descritas com maior detalhamento a seguir:
#
# 1. Definição de escopo da metodologia em termos de cobertura jurisdicional, objetivos e horizonte temporal;
# 2. Análise da necessidade de saúde bucal com base em aspectos da demografia, epidemiologia e serviços destinados da população a local;
# 3. Tradução do número de serviços em número de profissionais necessários;
# 4. Exploração das implicações em termos de recursos, como a oferta atual de profissionais e custos;
# 5. Análise de sensibilidade para simulação de parâmetros de incerteza;
# 6. Validação de modelo por meio de consulta a stakeholders.

# %% [markdown]
# ## Preparando ambiente do R
# ---
#
# Carregando os pacotes necessários para o Python.

# %%
#instalando os pacotes que ainda não foram instalados

#!pip install pyodbc
#!pip install geopandas
#!pip install rtree
#!pip install pygeos X
#!pip install mapclassify
#!pip install geobr
#!pip install python-dotenv

# %%
# Modelagem
import pandas as pd
import numpy as np

#execução dremio
import pyodbc
from dotenv import load_dotenv
load_dotenv()
import os

# Data View
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
from matplotlib.colors import Normalize
from matplotlib import cm
import matplotlib.ticker as ticker
import matplotlib.colors as mcolors
import itertools

#Mapas
import geopandas as gpd
import rtree
#import pygeos
import mapclassify
import geobr
from matplotlib.ticker import FuncFormatter

# %% [markdown]
# ## 1. Definição de escopo
# ---
# A metodologia tem como objetivo estimar a força de trabalho atual e necessária de cirurgiões dentistas e técnicos e auxilares de saúde bucal para atuação em municípios brasileiros, a nível de atenção primária, em procedimentos de natureza individual, bem como três procedimentos de natureza especializada: endodontia, prótese e periodontia.

# %% [markdown]
# ## 2. Análise das necessidades de saúde bucal
# ---
# A análise da necessidade de saúde bucal (NSB) foi construída a partir de três elementos: distribuição da população por faixa etária (P), prevalência de condições de saúde bucal (H) e procedimentos per capita (S).
#
# ![image.png](imagens/equacao1_sb.png)
#
# Onde:
#
# * NSB = Necessidade de saúde bucal é o número de serviços do tipo t destinados ao atendimento de população de faixa etária i e localidade l;
# * P = População por faixa-etária i de uma localidade l;
# * H = Prevalência de condições de saúde bucal que levam à necessidade de procedimentos do tipo t por faixa-etária i e dentro de uma localidade l;
# * S = Procedimentos per capita do tipo t, para cada faixa-etária i e dentro de uma localidade l.
#
# ### 2.1. Levantando a faixa etária (P)
#
# A distribuição por faixa etária foi construída com base em dados do último censo (2022) e estão disponíveis na página do IBGE.

# %%
pop_brasil = pd.read_excel("populacao_municipio_censo_completa.xlsx")
pop_brasil
# Out:
#       cod_municipiodv        municipio  ibge_sb  0 a 4 anos  5 a 9 anos  \
# 0             5300108         Brasília  5300108      166848      184611
# 1             5208707          Goiânia  5208707       83676       89501
# 2             5200050  Abadia de Goiás  5200000        1590        1619
# 3             5200100        Abadiânia  5200000        1171        1228
# 4             5200134          Acreúna  5200000        1384        1497
# ...               ...              ...      ...         ...         ...
# 5764          1101609        Theobroma  1300000         521         533
# 5765          1101708            Urupá  1300000         741         713
# 5766          1101757    Vale do Anari  1300000         516         597
# 5767          1101807  Vale do Paraíso  1300000         381         413
# 5768          1100304          Vilhena  1300000        7158        6948
#
#       10 a 14 anos  15 a 19 anos  20 a 24 anos  25 a 29 anos  30 a 34 anos  \
# ...

# %%
pop_brasil_tratado = pop_brasil [['cod_municipiodv', 'ibge_sb', 'municipio','de_0_a_14_anos','de_15_a_29_anos', 'de_30_a_59_anos','acima_de_60_anos']]
pop_brasil_tratado = pd.melt(pop_brasil_tratado, id_vars=['cod_municipiodv', 'ibge_sb', 'municipio'], var_name='faixa', value_name='total')
pop_brasil_tratado['faixa'] = pop_brasil_tratado['faixa'].replace('_',' ', regex= True)
pop_brasil_tratado['ibge_sb'] = pop_brasil_tratado['ibge_sb'].astype(str)
pop_brasil_tratado['ibge_sb'] = pop_brasil_tratado['ibge_sb'].str.slice(0,6)
pop_brasil_tratado['cod_municipiodv'] = pop_brasil_tratado['cod_municipiodv'].astype(str)
pop_brasil_tratado['cod_mun_loc'] = pop_brasil_tratado['cod_municipiodv']
pop_brasil_tratado['cod_municipiodv'] = pop_brasil_tratado['cod_municipiodv'].str.slice(0,6)
pop_brasil_tratado['id_faixa'] = np.where(pop_brasil_tratado['faixa'] == 'de 0 a 14 anos', 1,
                              np.where(pop_brasil_tratado['faixa'] == 'de 15 a 29 anos', 2,
                                       np.where(pop_brasil_tratado['faixa'] == 'de 30 a 59 anos',3,
                                                 np.where(pop_brasil_tratado['faixa'] == 'acima de 60 anos', 4, 0))))
pop_brasil_tratado
# Out:
#       cod_municipiodv ibge_sb        municipio             faixa   total  \
# 0              530010  530010         Brasília    de 0 a 14 anos  534233
# 1              520870  520870          Goiânia    de 0 a 14 anos  259141
# 2              520005  520000  Abadia de Goiás    de 0 a 14 anos    4810
# 3              520010  520000        Abadiânia    de 0 a 14 anos    3597
# 4              520013  520000          Acreúna    de 0 a 14 anos    4329
# ...               ...     ...              ...               ...     ...
# 23071          110160  130000        Theobroma  acima de 60 anos    1398
# 23072          110170  130000            Urupá  acima de 60 anos    1771
# 23073          110175  130000    Vale do Anari  acima de 60 anos    1181
# 23074          110180  130000  Vale do Paraíso  acima de 60 anos    1123
# 23075          110030  130000          Vilhena  acima de 60 anos   10670
#
#       cod_mun_loc  id_faixa
# 0         5300108         1
# 1         5208707         1
# ...

# %% [markdown]
# Plotando a informação de faixa etária. Nota-se que a faixa etária com maior frequência é de 30 a 59 anos.

# %%
# retirando as demais colunas para fazer o grafico
pop_brasil_tratado_grafico = pop_brasil_tratado[['faixa','total']]
pop_brasil_tratado_grafico = pop_brasil_tratado_grafico.groupby('faixa', as_index=False)['total'].sum()
pop_brasil_tratado_grafico
# Out:
#               faixa     total
# 0  acima de 60 anos  31643236
# 1    de 0 a 14 anos  41001697
# 2   de 15 a 29 anos  46121201
# 3   de 30 a 59 anos  86610211

# %%
# Ordenar a faixa etária
ordem = ['acima de 60 anos', 'de 30 a 59 anos', 'de 15 a 29 anos', 'de 0 a 14 anos']
pop_brasil_tratado_grafico['faixa'] = pd.Categorical(pop_brasil_tratado_grafico['faixa'], categories=ordem, ordered=True)

# Criar o gráfico de barras
plt.figure(figsize=(10, 6))
sns.barplot(data=pop_brasil_tratado_grafico, y='faixa', x='total')

# Formatar o eixo x para exibir números inteiros e com separador de milhar
def format_func(value, tick_number):
    return f'{int(value):,}'

plt.gca().xaxis.set_major_formatter(FuncFormatter(format_func))

plt.xlabel('Total')
plt.ylabel('Faixas')
plt.title('Distribuição de faixa etária por município')
plt.show()

# %% [markdown]
# O censo possui outras divisões de faixa etárias. Utilizamos estas para padronizar com os dados do próximo parâmetro (H), calculado a partir da pesquisa de SB 2010 (subseção seguinte).

# %% [markdown]
# ### 2.1.1. Plano de Saúde
# A seguir é feito um levantamento de plano de saúde por região de saúde de acordo com dados da ANS.

# %%
# Ler o arquivo CSV
hierarquia_municipios = pd.read_csv('hierarquia_atualizada.csv')
hierarquia_municipios['cod_municipio'] =hierarquia_municipios['cod_municipio'].astype(str)
hierarquia_municipios
# Out:
#                regiao_pad               regiao  cod_uf    uf_pad        uf  \
# 0            REGIAO NORTE         Região Norte      11  RONDONIA  Rondônia
# 1            REGIAO NORTE         Região Norte      11  RONDONIA  Rondônia
# 2            REGIAO NORTE         Região Norte      11  RONDONIA  Rondônia
# 3            REGIAO NORTE         Região Norte      11  RONDONIA  Rondônia
# 4            REGIAO NORTE         Região Norte      11  RONDONIA  Rondônia
# ...                   ...                  ...     ...       ...       ...
# 5565  REGIAO CENTRO-OESTE  Região Centro-Oeste      52     GOIAS     Goiás
# 5566  REGIAO CENTRO-OESTE  Região Centro-Oeste      52     GOIAS     Goiás
# 5567  REGIAO CENTRO-OESTE  Região Centro-Oeste      52     GOIAS     Goiás
# 5568  REGIAO CENTRO-OESTE  Região Centro-Oeste      52     GOIAS     Goiás
# 5569  REGIAO CENTRO-OESTE  Região Centro-Oeste      52     GOIAS     Goiás
#
#      uf_sigla  cod_macrorregiao              macrorregiao_pad  \
# ...

# %%
plano_de_saude = pd.read_csv('plano_de_saude.csv',  
    delimiter=',',  
    quotechar='"',  
    skipinitialspace=True)


plano_de_saude
# Out:
#        PERIODO  CD_MUNICIPIO  CD_UF SG_UF   FAIXA_CORRIGIDA  PLANO_ODONTO  \
# 0         2022        120030     12    AC    de 0 a 14 anos            12
# 1         2022        120010     12    AC   de 15 a 29 anos            33
# 2         2022        120010     12    AC  acima de 60 anos             9
# 3         2022        120040     12    AC   de 15 a 29 anos          3775
# 4         2022        120045     12    AC  acima de 60 anos            10
# ...        ...           ...    ...   ...               ...           ...
# 33625     2022        420425     42    SC              nada           157
# 33626     2022        420440     42    SC              nada             4
# 33627     2022        355370     35    SP              nada           210
# 33628     2022        352440     35    SP     Inconsistente             0
# 33629     2022        171510     17    TO              nada            11
#
#           POP
# 0        8926
# 1        6294
# 2        1671
# 3      105371
# ...

# %%
plano_de_saude['id_faixa'] = np.where(plano_de_saude['FAIXA_CORRIGIDA'] == 'de 0 a 14 anos', 1,
                              np.where(plano_de_saude['FAIXA_CORRIGIDA'] == 'de 15 a 29 anos', 2,
                                       np.where(plano_de_saude['FAIXA_CORRIGIDA'] == 'de 30 a 59 anos',3,
                                                 np.where(plano_de_saude['FAIXA_CORRIGIDA'] == 'acima de 60 anos', 4, 0))))
plano_de_saude = plano_de_saude.query('id_faixa != "NA"')
plano_de_saude['CD_MUNICIPIO'] =plano_de_saude['CD_MUNICIPIO'].astype(str)
#equivalente a função janitor
plano_de_saude.columns = plano_de_saude.columns.str.lower()  
plano_de_saude.columns = plano_de_saude.columns.str.replace(' ', '_')  
plano_de_saude.columns = plano_de_saude.columns.str.replace(r'[^\w\s]', '', regex=True)
plano_de_saude = plano_de_saude[['cd_municipio', 'id_faixa', 'plano_odonto', 'pop']]

plano_de_saude
# Out:
#       cd_municipio  id_faixa  plano_odonto     pop
# 0           120030         1            12    8926
# 1           120010         2            33    6294
# 2           120010         4             9    1671
# 3           120040         2          3775  105371
# 4           120045         4            10    1630
# ...            ...       ...           ...     ...
# 33625       420425         0           157     966
# 33626       420440         0             4     656
# 33627       355370         0           210    3715
# 33628       352440         0             0       0
# 33629       171510         0            11     420
#
# [33630 rows x 4 columns]

# %%
plano_odontologico_rs = pd.merge(plano_de_saude, hierarquia_municipios, how  = 'left', left_on = ['cd_municipio'],right_on = ['cod_municipio'])
plano_odontologico_rs = plano_odontologico_rs.groupby(['uf','uf_sigla','cod_regsaud','regiao_saude','id_faixa'], as_index= False).agg(benef=('plano_odonto', 'sum'),pop=('pop', 'sum'))
plano_odontologico_rs["cobertura_plano"] = plano_odontologico_rs["benef"] / plano_odontologico_rs["pop"]
plano_odontologico_rs = plano_odontologico_rs[plano_odontologico_rs["pop"] != 0]

plano_odontologico_rs
# Out:
#              uf uf_sigla  cod_regsaud   regiao_saude  id_faixa  benef    pop  \
# 0          Acre       AC      12001.0      Alto Acre         0     27   6679
# 1          Acre       AC      12001.0      Alto Acre         1     37  13286
# 2          Acre       AC      12001.0      Alto Acre         2     68  17209
# 3          Acre       AC      12001.0      Alto Acre         3    190  19090
# 4          Acre       AC      12001.0      Alto Acre         4     28   4623
# ...         ...      ...          ...            ...       ...    ...    ...
# 2245  Tocantins       TO      17008.0  Amor Perfeito         0    443  14788
# 2246  Tocantins       TO      17008.0  Amor Perfeito         1    733  30472
# 2247  Tocantins       TO      17008.0  Amor Perfeito         2   1463  44178
# 2248  Tocantins       TO      17008.0  Amor Perfeito         3   3966  52997
# 2249  Tocantins       TO      17008.0  Amor Perfeito         4   1626  15218
#
#       cobertura_plano
# ...

# %% [markdown]
# Vamos agora unir à tabela de população possui.

# %%
relacao_municipio_rs = hierarquia_municipios[['cod_municipio','cod_regsaud']]
populacao_tratado = pd.merge(pop_brasil_tratado,relacao_municipio_rs, how  = 'left', left_on = ['cod_municipiodv'],right_on = ['cod_municipio'])
populacao_tratado = pd.merge(populacao_tratado, plano_odontologico_rs, how='left', on=['cod_regsaud', 'id_faixa'])
populacao_tratado = populacao_tratado.drop(columns=['benef', 'pop'])
populacao_tratado['pop_sus'] = populacao_tratado['total'] * (1 - populacao_tratado['cobertura_plano'])

populacao_tratado
# Out:
#       cod_municipiodv ibge_sb        municipio             faixa   total  \
# 0              530010  530010         Brasília    de 0 a 14 anos  534233
# 1              520870  520870          Goiânia    de 0 a 14 anos  259141
# 2              520005  520000  Abadia de Goiás    de 0 a 14 anos    4810
# 3              520010  520000        Abadiânia    de 0 a 14 anos    3597
# 4              520013  520000          Acreúna    de 0 a 14 anos    4329
# ...               ...     ...              ...               ...     ...
# 23071          110160  130000        Theobroma  acima de 60 anos    1398
# 23072          110170  130000            Urupá  acima de 60 anos    1771
# 23073          110175  130000    Vale do Anari  acima de 60 anos    1181
# 23074          110180  130000  Vale do Paraíso  acima de 60 anos    1123
# 23075          110030  130000          Vilhena  acima de 60 anos   10670
#
#       cod_mun_loc  id_faixa cod_municipio  cod_regsaud                uf  \
# ...

# %% [markdown]
# A variável pop_sus será útil para simular os resultados usando a população que não tem acesso a plano de saúde (exclusivamente odontológico)

# %% [markdown]
# ### 2.2. Cobertura de condições de saúde bucal (H)
#
# O Ministério da Saúde traz uma série de parâmetros para planejamento dos serviços de saúde bucal (Brasil, 2021). Um dos parâmetros é a cobertura de serviços de saúde. A cobertura foi calculada a partir da pesquisa SB 2010 para cada faixa etária e tipo de procedimento conforme a lógica expressa abaixo.
#
# Cabe destacar que, devido à estrutura da SB2010, estes parâmetros foram calculados para capitais de cada estado ou interior da região.
#
#                                                             Fonte: Brasil (2021)
# ---
# ### **Área** |**Expressões usadas para cálculo de cobertura**
# ---
# **Atenção básica:**	NT_1 (Número de dentes necessitando de restauração de 1 superfície) + NT_2 (Número de dentes necessitando de restauração de 2 ou     mais    superfícies) + NT_6 (Número de dentes necessitando de extração) + NT_7 (Número de dentes necessitando de controle de lesão branca) + NT_8 (Número de dentes necessitando de selante) + P_CALC (Prevalência de cálculo) + P_BR (Prevalência de bolsa rasa). Foi então criada a variável COB_AB. Se COB_AB = 0 o indivíduo não necessita de procedimentos de atenção básica, se COB_AB =1 ele necessita. A cobertura de atenção básica foi então estimada pelo percentual de pessoas com COB_AB=1
#
# ---
# **Endodontia:**	A cobertura de endodontia foi calculada a partir da variável NT_5 (Número de dentes necessitando de tratamento pulpar + restauração). Foi criada a variável ENDO onde ENDO=0 se NT_5=0 e ENDO=1 se NT_5≠0. Desta forma, a cobertura de endodontia foi então estimada pelo percentual de pessoas com ENDO=1
#
# ---
# **Periodontia especializada:**	A cobertura de periodontia especializada foi estimada pelo percentual de pessoas com a variável P_BP (Prevalência de bolsa profunda) = 1
#
# ---
# **Prótese:**	A cobertura de prótese foi calculada pelo percentual de pessoas com a variável NECPROT (Necessidade geral de prótese) ≠ 0
#
# ---
#
# A cobertura de saúde bucal para cada condição e faixa etária são apresentados abaixo.

# %%
# Lendo dados
cobertura_sb = pd.read_excel("cobertura sb.xlsx",sheet_name="Cobertura")
cobertura_sb['ibge'] = cobertura_sb['ibge'].astype(str)
cobertura_sb['ibge'] = cobertura_sb['ibge'].str.slice(0,6)

# apresentando dados
print(cobertura_sb.drop(columns=['ibge', 'id_faixa','li_cobertura','ls_cobertura']))
# Out:
#        municipio    procedimento     faixa_etaria  cobertura
# 0    Porto Velho  Atenção Básica      0 a 14 anos      0.690
# 1    Porto Velho      Endodontia      0 a 14 anos      0.074
# 2    Porto Velho     Periodontia      0 a 14 anos      0.000
# 3    Porto Velho         Prótese      0 a 14 anos      0.000
# 4     Rio Branco  Atenção Básica      0 a 14 anos      0.625
# ..           ...             ...              ...        ...
# 507     Brasília     Periodontia  60 anos ou mais      0.023
# 508     Brasília         Prótese      0 a 14 anos      0.000
# 509     Brasília         Prótese     15 a 29 anos      0.078
# 510     Brasília         Prótese     30 a 59 anos      0.737
# 511     Brasília         Prótese  60 anos ou mais      0.626
#
# [512 rows x 4 columns]

# %% [markdown]
# Considerando os dados de população (P) e de cobertura (H), temos os seguintes resultados para população coberta.

# %%
# tratando os dados devido ao padrao de codigo IBGE de 7 digitos em algumas bases

populacao_tratado['ibge_sb'] = populacao_tratado['ibge_sb'].astype(str)
populacao_tratado['ibge_sb'] = populacao_tratado['ibge_sb'].str.slice(start=0, stop=6)

cobertura_sb['ibge'] = cobertura_sb['ibge'].astype(str)

# juntando base de populacao e cobertura de saude bucal

pop_coberta_br =  pd.merge(populacao_tratado,cobertura_sb, how  = 'left', left_on = ['ibge_sb', 'id_faixa'],right_on = ['ibge','id_faixa'])
pop_coberta_br = pop_coberta_br[['ibge', 'ibge_sb', 'municipio_x', 'faixa','id_faixa', 'total', 'procedimento', 'cobertura', 'cobertura_plano', 'pop_sus', 'cod_municipiodv', 'cod_mun_loc']]
pop_coberta_br = pop_coberta_br.rename(columns={'municipio_x': 'municipio'})
pop_coberta_br = pop_coberta_br.rename(columns={'cobertura': 'cobertura_servicos'})
pop_coberta_br['populacao_coberta'] = (pop_coberta_br['cobertura_servicos'] * pop_coberta_br['total']).round(2)
pop_coberta_br['populacao_coberta_sus'] = (pop_coberta_br['cobertura_servicos'] * pop_coberta_br['pop_sus']).round(2)

pop_coberta_br
# Out:
#          ibge ibge_sb        municipio             faixa  id_faixa   total  \
# 0      530010  530010         Brasília    de 0 a 14 anos         1  534233
# 1      530010  530010         Brasília    de 0 a 14 anos         1  534233
# 2      530010  530010         Brasília    de 0 a 14 anos         1  534233
# 3      530010  530010         Brasília    de 0 a 14 anos         1  534233
# 4      520870  520870          Goiânia    de 0 a 14 anos         1  259141
# ...       ...     ...              ...               ...       ...     ...
# 92299  130000  130000  Vale do Paraíso  acima de 60 anos         4    1123
# 92300  130000  130000          Vilhena  acima de 60 anos         4   10670
# 92301  130000  130000          Vilhena  acima de 60 anos         4   10670
# 92302  130000  130000          Vilhena  acima de 60 anos         4   10670
# 92303  130000  130000          Vilhena  acima de 60 anos         4   10670
#
# ...

# %% [markdown]
# ### 2.3. Parâmetros normativos de procedimentos per capita (S)
# Os cálculos de necessidade normativa por procedimento per capita (S) estão disponíveis nos parâmetros do Ministério da Saúde e são baseados na pesquisa de Saúde Bucal (SB 2010).
#
#
#                                                          Fonte: Brasil (2021)
#
# ---
#
# **Área** |	**Procedimentos**
#
# ---
# **Atenção básica:** No banco de dados do projeto SB BRASIL 2010 foram transformados os códigos 0 (hígido), A (não examinado) e X (excluído) das variáveis CPI17, CPI11, CPI 27, CPI37, CPI31 e CPI47 em 0 e em 1 para as variáveis que tivessem o código 2 (cálculo) e 3 (bolsa rasa).
#
# Ao final essas variáveis foram somadas e a variável NECPERIO_AB criada para armazenar esta soma.
#
# Foram somados os valores referentes as variáveis NT_1, NT_2, NT_6, NT_7 e NT_8 formando a variável NEC_AB. Finalmente foram somadas NECPERIO_AB e NEC_AB para se obter a variável NEC_AB_TOTAL.
#
# Foi então obtida a média da variável NEC_AB_TOTAL estratificada por idade e domínios geográficos (capitais e interior).
#
# ---
# **Endodontia:**	Foi obtida a média da variável NT_5 (Número de dentes necessitando de tratamento pulpar + restauração) estratificada por idade e domínios geográficos (capitais e interior).
#
# ---
# **Periodontia:** No banco de dados do projeto SB BRASIL 2010 foram transformados os códigos 0 (hígido), A (não examinado) e X (excluído) das variáveis CPI17, CPI11, CPI 27, CPI37, CPI31 e CPI47 em 0 e em 1 para as variáveis que tivessem o código 4 (bolsa profunda).
#
# Ao final essas variáveis foram somadas e a variável NECPERIO_ESPEC criada para armazenar esta soma.
#
# Foi então obtida a média da variável NECPERIO_ESPEC estratificada por idade e domínios geográficos (capitais e interior). Para as idades de 5 e 12 anos esta variável não foi mensurada no projeto SB BRASIL 2010, portanto não há dados de necessidade normativa para a faixa de 0 a 14 anos.
#
# ---
# **Prótese:** A variável NECPROT foi transformada em NUMPROT (número de próteses) como explicitado a seguir:
#
# + Se NECPROT = 0 (Não necessita), então NUMPROT = 0
# + Se NECPROT = 1 (Parcial 1 maxilar), então NUMPROT = 1
# + Se NECPROT = 2 (Parcial 2 maxilares), então NUMPROT = 2
# + Se NECPROT = 3 (Total 1 maxilar), então NUMPROT = 3
# + Se NECPROT = 4 (Parcial + total), então NUMPROT = 2
# + Se NECPROT = 5 (Total 2 maxilares), então NUMPROT = 2
# + Se NECPROT = 9 (Sem informação), então NUMPROT = 0
#
# Foi então obtida a média da variável NUMPROT estratificada por idade e domínios geográficos (capitais e interior).
#
# Para as idades de 5 e 12 anos esta variável não foi mensurada no projeto SB BRASIL 2010, portanto não há dados de necessidade normativa para a faixa de 0 a 14 anos.
#
# ---
#
# O código abaixo acessa dados de produção normativa em Palmas-TO, disponível nos parâmetros do Ministério da Saúde.

# %%
# leitura do dado de producao normativa (S)
col_tipos = {'ibge': str, 'municipio': str,
            'procedimento':str, 'faixa_etaria':str,
             'id_faixa':int, 'producao_pc':float,
            'li_cobertura':float,'ls_cobertura':float}

producao_normativa_br = pd.read_excel("cobertura sb.xlsx",sheet_name="Produção normativa",dtype= col_tipos)
producao_normativa_br['ibge'] = producao_normativa_br['ibge'].str.slice(0,6)
producao_brasil = producao_normativa_br.drop(columns=['municipio','li_cobertura','ls_cobertura','faixa_etaria'])

# juntando populacao coberta e producao normativa para calcular o total de servicos necessarios

necessidades_servicos_br = pd.merge(pop_coberta_br, producao_brasil, how = 'left', on = ['ibge','id_faixa','procedimento'])
necessidades_servicos_br['nec_servicos']= (necessidades_servicos_br['populacao_coberta']* necessidades_servicos_br['producao_pc']).round(2) 
necessidades_servicos_br['nec_servicos_sus']= (necessidades_servicos_br['populacao_coberta_sus']* necessidades_servicos_br['producao_pc']).round(2)


print(necessidades_servicos_br[['municipio','faixa','total','procedimento','nec_servicos','nec_servicos_sus']]
      .rename(columns ={'total':'populacao'}).groupby(['faixa', 'procedimento'], as_index= False)
      .agg(populacao=('populacao', 'sum'),
           servicos=('nec_servicos', 'sum'),
           servicos_sus=('nec_servicos_sus','sum')))
# Out:
#                faixa    procedimento  populacao      servicos  servicos_sus
# 0   acima de 60 anos  Atenção Básica   31643236  1.824375e+07  1.611917e+07
# 1   acima de 60 anos      Endodontia   31643236  2.051368e+04  1.789331e+04
# 2   acima de 60 anos     Periodontia   31643236  5.115949e+04  4.485926e+04
# 3   acima de 60 anos         Prótese   31643236  3.606569e+07  3.249070e+07
# 4     de 0 a 14 anos  Atenção Básica   41001697  7.082615e+07  6.642993e+07
# 5     de 0 a 14 anos      Endodontia   41001697  4.051116e+05  3.790983e+05
# 6     de 0 a 14 anos     Periodontia   41001697  0.000000e+00  0.000000e+00
# 7     de 0 a 14 anos         Prótese   41001697  0.000000e+00  0.000000e+00
# 8    de 15 a 29 anos  Atenção Básica   46121201  1.221639e+08  1.095967e+08
# 9    de 15 a 29 anos      Endodontia   46121201  6.414030e+05  5.797138e+05
# 10   de 15 a 29 anos     Periodontia   46121201  9.917370e+03  8.767300e+03
# ...

# %% [markdown]
# ## 3. Tradução do número de serviços em número de profissionais necessários
#
# A etapa 3 consiste na tradução do número de serviços, calculado pela equação 1, em número de profissionais necessários (NPSB). Para isso, devem ser considerados dois elementos: produtividade (T) e o tempo total disponível (TTD).
#
# ![image.png](imagens/eq2_sb.png)
#
# Onde:
#
# + NPSB = Necessidade de profissionais de saúde bucal;
# + NSB = Necessidade de saúde bucal contabilizada pelo número de serviços do tipo t destinados ao atendimento de população de faixa etária i e localidade l;
# + T = Tempo médio de serviços do tipo t;
# + TTD = Tempo total disponível de um profissional ao longo de um ano.
#
# Vamos utilizar como tempo médio de consulta (T) o valor de 25 minutos. Esse valor foi baseado em um levantamento utilizando técnicas de time-motion realizado para aferir o tempo médio de procedimentos executados pela equipe de saúde bucal, em unidades básicas de saúde em São Paulo, Brasil (Bellotti et al, 2024).
#
# O tempo total disponível (TTD) corresponde ao tempo de um profissional deduzidas ausências programáticas (ex.: férias, feriados) e não programáticos (ex.: licenças para tratamento de saúde). Vamos utilizar como referência o TTD estimado em 1576 horas, frequentemente usado para enfermeiros. Infelizmente, não temos estudos que já tenham levantado um TTD para profissionais de saúde bucal no Brasil.
#
# Este resultado indica quantos cirurgiões dentistas por mês são necessários ao longo de um ano para cobrir as necessidades da população.

# %%
necessidades_prof_br = necessidades_servicos_br.copy()
necessidades_prof_br['nec_prof'] = necessidades_prof_br.apply(
    lambda row: (row['nec_servicos'] * (45/60)) / 1576 if row['procedimento'] in ["Atenção Básica", "Endodontia"] else
                (row['nec_servicos'] * (55/60)) / 1576 if row['procedimento'] in ["Periodontia", "Prótese"] else None,
    axis=1
)

necessidades_prof_br['nec_prof_sus'] = necessidades_prof_br.apply(
    lambda row: (row['nec_servicos_sus'] * (45/60)) / 1576 if row['procedimento'] in ["Atenção Básica", "Endodontia"] else
                (row['nec_servicos_sus'] * (55/60)) / 1576 if row['procedimento'] in ["Periodontia", "Prótese"] else None,
    axis=1
)

necessidades_prof_br['nivel'] = np.where(necessidades_prof_br['procedimento'] == "Atenção Básica", "APS", "AES")
necessidades_prof_br = necessidades_prof_br.groupby(['ibge', 'municipio', 'nivel', 'cod_municipiodv', 'cod_mun_loc'], as_index= False).agg(necessidade=('nec_prof', 'sum'),necessidade_sus=('nec_prof_sus', 'sum')).round(2) 



# Selecionando as colunas específicas
print(necessidades_prof_br[['municipio', 'nivel', 'necessidade', 'necessidade_sus']].reset_index(drop=True))
# Out:
#                    municipio nivel  necessidade  necessidade_sus
# 0                Porto Velho   AES       126.44           104.02
# 1                Porto Velho   APS       776.13           664.44
# 2                 Rio Branco   AES       152.62           145.27
# 3                 Rio Branco   APS       397.26           381.48
# 4                 Abaetetuba   AES        58.16            54.60
# ...                      ...   ...          ...              ...
# 11135  Águas Lindas de Goiás   APS       346.07           311.27
# 11136                Goiânia   AES       383.70           298.22
# 11137                Goiânia   APS       804.74           627.39
# 11138               Brasília   AES       772.37           516.97
# 11139               Brasília   APS      2491.68          1742.91
#
# [11140 rows x 4 columns]

# %% [markdown]
# ## 4. Exploração das implicações em termos de recursos, como a oferta atual de profissionais e custos
# ---
# O próximo passo consiste em algumas etapas, sendo elas:
#
# 1. Obtenção da oferta de profissionais;
# 2. Cálculo de valor líquido da oferta;
# 3. Comparação da oferta com necessidades;
#
# ### 4.1. Obtenção da oferta de profissionais
# A oferta de profissionais foi acessada usando o Cadastro Nacional de Estabelecimentos de Saúde - tabela Profissionais (CNES-PF).
#
# Como profissionais podem ter múltiplos vínculos, padronizou-se a contagem por meio do Full-time equivalent (FTE), com base na carga horária de contrato.

# %%
# codigo para acessar dados de datalake proprio

host = os.environ['host']
port = os.environ['port']
uid = os.environ['usuario']
pwd = os.environ['senha']
driver = os.environ['driver']

channel = pyodbc.connect("DRIVER={};HOST={};PORT={};UID={};PWD={};AUTHENTICATIONTYPE=Basic Authentication;CONNECTIONTYPE=Direct".format(driver, host,port,uid,pwd),autocommit=True)

query = '''SELECT * FROM "Analytics Layer".Infraestrutura.Profissionais."TSB e dentistas por municipio"'''

oferta = pd.read_sql(query,channel)
oferta.head()
# Out:
# C:\Users\lapei\AppData\Local\Temp\ipykernel_21060\1972585457.py:13: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   oferta = pd.read_sql(query,channel)
#   CODUFMUN PROF_SUS NIVEL FAM_CBO                           CATEGORIA   CH  \
# 0   260005        1   APS    3224  Técnico ou Auxiliar de Saúde Bucal  770
# 1   260330        1   APS    2232                  Cirurgião-dentista  200
# 2   260370        1   AES    2232                  Cirurgião-dentista  154
# 3   260545        1   APS    2232                  Cirurgião-dentista   80
# 4   260640        1   APS    3224  Técnico ou Auxiliar de Saúde Bucal  960
#
#    fte40
# 0  19.25
# 1   5.00
# 2   3.85
# 3   2.00
# 4  24.00

# %% [markdown]
# A consulta `SQL` que gerou esta tabela de dados está descrito abaixo.
#
# Acessamos dados de todos os municípios para a `COMPETEN` (mês e ano) de janeiro de 2024. Foram acessados dados de Cirurgiões dentistas e Técnicos e Auxiliares de Saúde Bucal. Acessamos registros de profissionais atuantes no SUS e na saúde suplementar a partir da variável `PROF_SUS`. Para uma primeira análise vamos fazer simulações apenas para o recorte de profissionais SUS.
#
# Foram acessados dados dos seguintes tipos de unidade (`TP_UNID`):
#
# + Atenção Primária à Saúde (APS)
# ◦01 - Posto de saúde
# ◦02 - Centro de Saúde/Unidade Básica
# ◦32 - Unidade Móvel Fluvial
# ◦40 - Unidade Móvel Terrestre
# + Atenção Especializada à Saúde (AES)
# ◦36 - Clínica/Centro de Especialidade
# ◦73 - Pronto atendimento
# ◦04 - Policlínica
# ◦22 - Consultório Isolado
#
# Não foi incluída a força de trabalho atuante em hospitais, tendo em vista o escopo da metodologia.

# %% [markdown]
# ```sql
#
# WITH PROF AS(
#
#     SELECT
#         CNES,
#         CODUFMUN,
#         COMPETEN,
#         PROF_SUS,
#             CASE
#               WHEN TP_UNID = '01' OR
#                    TP_UNID = '02' OR
#                    TP_UNID = '32' OR
#                    TP_UNID = '40' THEN  'APS'
#               WHEN TP_UNID = '36' OR
#                    TP_UNID = '73' OR
#                    TP_UNID = '04' OR
#                    TP_UNID = '22' THEN 'AES'
#             END NIVEL,
#             SUBSTR(CBO, 1, 4) AS FAM_CBO,
#             CASE
#                 WHEN substr(CBO, 1, 4) = '2232'
#                   THEN 'Cirurgião-dentista'
#                 WHEN substr(CBO, 1, 4) = '3224'
#                   THEN 'Técnico ou Auxiliar de Saúde Bucal'
#             END CATEGORIA,
#             (HORAOUTR + HORAHOSP + HORA_AMB) AS ch_total,
#             CAST((CAST(HORAOUTR + HORAHOSP + HORA_AMB AS FLOAT)/CAST(40 AS FLOAT)) AS FLOAT) AS fte40
#
#     FROM Dados.cnes.PF pf
#
#     WHERE (substr(CBO, 1, 4) = '2232' OR
#             substr(CBO, 1, 4) = '3224') AND
#             COMPETEN = '202401' AND
#             NIVEL IS NOT NULL
#
# )
#
# SELECT CODUFMUN,
#        PROF_SUS,
#        NIVEL,
#        FAM_CBO,
#        CATEGORIA,
#        SUM(ch_total) AS CH,
#        ROUND(SUM(fte40),2) AS fte40
# FROM PROF
# GROUP BY
#        CODUFMUN,
#        PROF_SUS,
#        NIVEL,
#        FAM_CBO,
#        CATEGORIA

# %% [markdown]
# O script abaixo fazer alguns tratamentos em relação à oferta, pois nem todos os municípios terão profissionais em atenção especializada, por exemplo.
#
# Temos que assegurar que tenhamos 44560 linhas na tabela (5570 municípios x dois níveis de atenção x duas categorias profissionais x dois tipos de vínculo, SUS e não SUS). Por isso é feito o tratamento abaixo.

# %%
# Definindo o vetor com 5570 município
vetor = necessidades_prof_br['cod_municipiodv'].unique()


# Cada elemento do vetor será repetido 8 vezes (2 valores para 'nível', 2 valores para 'profissional' e 2 valores para 'SUS')
vetor_duplicado = [item for item in vetor for _ in range(8)]

# Criando a coluna 'nível' com valores alternados entre 'APS' e 'AES'

tamanho_vetor_duplicado = len(vetor_duplicado) # para que o tamanho seja igual o vetor_duplicado
padrao = ['APS', 'APS', 'APS', 'APS', 'AES', 'AES', 'AES', 'AES'] # indicando quais são os vetores para repetir, ja replicado o número de vezes para simplificar o código

nivel = np.resize(padrao, tamanho_vetor_duplicado) #essa função usa o padrão definido anteriormente e faz de acordo com o tamanho do vetor indicado

# Criando a coluna 'profissional' com valores alternados entre 'dentista' e 'TSB'
padrao2= ['2232','2232', '3224','3224']
profissional = np.resize(padrao2, tamanho_vetor_duplicado)

# Criando a coluna 'SUS' com valores alternados entre 0 e 1
padrao3 = ['0','1']
SUS = np.resize(padrao3, tamanho_vetor_duplicado) 

# Criando o DataFrame
df = pd.DataFrame({
    'elemento': vetor_duplicado,
    'nivel': nivel,
    'profissional': profissional,
    'SUS': SUS
})

df.rename(columns={'elemento': 'ibge'}, inplace=True)

#igualando os tipos de coluna para fazer o left join
df['ibge']= df['ibge'].astype(str)

oferta_brasil = pd.merge(df, oferta, how  = 'left', left_on = ['ibge','nivel','SUS','profissional'],right_on = ['CODUFMUN','NIVEL','PROF_SUS','FAM_CBO'])
oferta_brasil['fte40'] = oferta_brasil['fte40'] .fillna(0)
oferta_brasil['CH'] = oferta_brasil['CH'] .fillna(0)

oferta_brasil
# Out:
#          ibge nivel profissional SUS CODUFMUN PROF_SUS NIVEL FAM_CBO  \
# 0      110020   APS         2232   0   110020        0   APS    2232
# 1      110020   APS         2232   1   110020        1   APS    2232
# 2      110020   APS         3224   0   110020        0   APS    3224
# 3      110020   APS         3224   1   110020        1   APS    3224
# 4      110020   AES         2232   0   110020        0   AES    2232
# ...       ...   ...          ...  ..      ...      ...   ...     ...
# 44555  530010   APS         3224   1   530010        1   APS    3224
# 44556  530010   AES         2232   0   530010        0   AES    2232
# 44557  530010   AES         2232   1   530010        1   AES    2232
# 44558  530010   AES         3224   0   530010        0   AES    3224
# 44559  530010   AES         3224   1   530010        1   AES    3224
#
#                                 CATEGORIA       CH    fte40
# 0                      Cirurgião-dentista     40.0     1.00
# ...

# %% [markdown]
# ### 4.2. Cálculo de valor líquido da oferta
# O cálculo do valor líquido da oferta é feito por meio da fórmula 3:
#
# ![image.png](imagens/eq3_sb.png)
#
# Onde:
#
# + O = Oferta de profissionais em dada localidade l;
# + E = Total de profissionais atuantes em estabelecimentos de saúde em dada localidade l;
# + AD = Percentual da carga de trabalho dedicada a atividades diretas (%);
# + FC = Percentual da carga de trabalho dedicada a um foco clínico (%)
#
# Não temos números associados a AD e FC. Vamos utilizar os valores abaixo, no entanto, já pensando na simulação mais a frente.

# %%
# calculando a oferta de profissionais apos deducao de carga de trabalho dedicada a atividades diretas e ao foco clinico. 
oferta_brasil['FTE_40_direto'] = oferta_brasil['fte40']* 0.40 
oferta_brasil['FTE_40_linha'] = oferta_brasil['FTE_40_direto']* 0.50 
oferta_brasil
# Out:
#          ibge nivel profissional SUS CODUFMUN PROF_SUS NIVEL FAM_CBO  \
# 0      110020   APS         2232   0   110020        0   APS    2232
# 1      110020   APS         2232   1   110020        1   APS    2232
# 2      110020   APS         3224   0   110020        0   APS    3224
# 3      110020   APS         3224   1   110020        1   APS    3224
# 4      110020   AES         2232   0   110020        0   AES    2232
# ...       ...   ...          ...  ..      ...      ...   ...     ...
# 44555  530010   APS         3224   1   530010        1   APS    3224
# 44556  530010   AES         2232   0   530010        0   AES    2232
# 44557  530010   AES         2232   1   530010        1   AES    2232
# 44558  530010   AES         3224   0   530010        0   AES    3224
# 44559  530010   AES         3224   1   530010        1   AES    3224
#
#                                 CATEGORIA       CH    fte40  FTE_40_direto  \
# ...

# %% [markdown]
# ### 4.3. Implicações de resultados em termos quantitativos
# Por fim, são feitos os cálculos entre oferta e necessidade. São aplicadas duas métricas:
#
# + Resultado Absoluto (RA), que é referente à diferença entre oferta e necessidade, conforme equação 4;
#
# + Resultado Relativo (RR), que se refere à diferença percentual entre oferta e necessidade, conforme equação 5.
#
# ![imagem.png](imagens/eq4_sb.png)
#
# Onde:
#
# + RA = Resultado absoluto;
# + O = Oferta de cirurgiões-dentistas em dada localidade l;
# + NPSB = Necessidade de cirurgiões-dentistas em dada localidade l;
#
# ![imagem.png](imagens/eq5_sb.png)
#
# Onde:
#
# + RR = Resultado relativo;
# + O = Oferta de cirurgiões-dentistas em dada localidade l;
# + NPSB = Necessidade de cirurgiões-dentistas em dada localidade l;
#
# Os cálculos são realizados conforme os scripts:

# %% [markdown]
# ### 4.3.1. Resultado a nível município

# %%
oferta_brasil_cd = oferta_brasil[(oferta_brasil['profissional'] == "2232") & (oferta_brasil['SUS'] == '1')]
hierarquia_municipios['cod_municipio']= hierarquia_municipios['cod_municipio'].astype(str)


cd_oferta_vs_demanda_br = pd.merge(necessidades_prof_br,oferta_brasil_cd, how='left', left_on= ['cod_municipiodv','nivel'], right_on=['ibge','nivel'])
cd_oferta_vs_demanda_br = pd.merge(cd_oferta_vs_demanda_br, hierarquia_municipios, how='left', left_on= ['cod_municipiodv'], right_on=['cod_municipio'])


cd_oferta_vs_demanda_br['FTE_40_linha'] = cd_oferta_vs_demanda_br['FTE_40_linha'].fillna(0)
cd_oferta_vs_demanda_br['fte40'] = cd_oferta_vs_demanda_br['fte40'].fillna(0)
cd_oferta_vs_demanda_br['FTE_40_direto'] = cd_oferta_vs_demanda_br['FTE_40_direto'].fillna(0)


cd_oferta_vs_demanda_br['ra'] = cd_oferta_vs_demanda_br['FTE_40_linha']- cd_oferta_vs_demanda_br['necessidade'].round(2)
cd_oferta_vs_demanda_br['rr'] = (cd_oferta_vs_demanda_br['FTE_40_linha']/cd_oferta_vs_demanda_br['necessidade']* 100).round(2)
cd_oferta_vs_demanda_br['ra_s'] = cd_oferta_vs_demanda_br['FTE_40_linha']- cd_oferta_vs_demanda_br['necessidade_sus'].round(2)
cd_oferta_vs_demanda_br['rr_s'] = (cd_oferta_vs_demanda_br['FTE_40_linha']/cd_oferta_vs_demanda_br['necessidade_sus']*100).round(2)
cd_oferta_vs_demanda_br['necessidade'] = cd_oferta_vs_demanda_br['necessidade'].round(2)
cd_oferta_vs_demanda_br['FTE_40_linha'] = cd_oferta_vs_demanda_br['FTE_40_linha'].round(2)

cd_oferta_vs_demanda_br = cd_oferta_vs_demanda_br.drop(columns=['ibge_y'])
cd_oferta_vs_demanda_br= cd_oferta_vs_demanda_br.rename(columns = {'ibge_x':'ibge'})
cd_oferta_vs_demanda_br = cd_oferta_vs_demanda_br.drop(columns=['cod_municipiodv_y'])
cd_oferta_vs_demanda_br= cd_oferta_vs_demanda_br.rename(columns = {'cod_municipiodv_x':'cod_municipiodv'})

cd_oferta_vs_demanda_br = cd_oferta_vs_demanda_br[['ibge', 'regiao_pad', 'uf_sigla', 'cod_regsaud',
                                                   'regiao_saude', 'municipio_pad', 'nivel',
                                                   'necessidade', 'necessidade_sus', 'FTE_40_linha',
                                                   'rr', 'ra', 'rr_s', 'ra_s', 'cod_municipiodv', 'cod_mun_loc']]


print(cd_oferta_vs_demanda_br.drop(columns=['cod_mun_loc','cod_municipiodv']))
# Out:
#          ibge           regiao_pad uf_sigla  cod_regsaud        regiao_saude  \
# 0      110020         REGIAO NORTE       RO        11004      Madeira-Mamoré
# 1      110020         REGIAO NORTE       RO        11004      Madeira-Mamoré
# 2      120040         REGIAO NORTE       AC        12002  Baixo Acre e Purus
# 3      120040         REGIAO NORTE       AC        12002  Baixo Acre e Purus
# 4      130000         REGIAO NORTE       PA        15011           Tocantins
# ...       ...                  ...      ...          ...                 ...
# 11135  520000  REGIAO CENTRO-OESTE       GO        52004         Entorno Sul
# 11136  520870  REGIAO CENTRO-OESTE       GO        52001             Central
# 11137  520870  REGIAO CENTRO-OESTE       GO        52001             Central
# 11138  530010  REGIAO CENTRO-OESTE       DF        53001    Distrito Federal
# 11139  530010  REGIAO CENTRO-OESTE       DF        53001    Distrito Federal
#
# ...

# %% [markdown]
# ### 4.3.2. Resultado a nível região de saúde

# %%
resultado_rs = cd_oferta_vs_demanda_br.groupby(['nivel','regiao_pad','uf_sigla','cod_regsaud','regiao_saude'], as_index= False).agg(necessidade=('necessidade','sum'),necessidade_sus=('necessidade_sus','sum'),oferta=('FTE_40_linha','sum'))

resultado_rs['ra'] = resultado_rs['oferta']- resultado_rs['necessidade'].round(2)
resultado_rs['rr'] = (resultado_rs['oferta']/resultado_rs['necessidade']* 100).round(2)
resultado_rs['ra_s'] = resultado_rs['oferta']- resultado_rs['necessidade_sus'].round(2)
resultado_rs['rr_s'] = (resultado_rs['oferta']/resultado_rs['necessidade_sus']*100).round(2)

resultado_rs['rr'] = np.where(resultado_rs['rr'] == 0.00, 0.01,resultado_rs['rr'])
resultado_rs['rr_s'] = np.where(resultado_rs['rr_s'] == 0.00, 0.01, resultado_rs['rr_s'])

resultado_rs
# Out:
#     nivel           regiao_pad uf_sigla  cod_regsaud             regiao_saude  \
# 0     AES  REGIAO CENTRO-OESTE       DF        53001         Distrito Federal
# 1     AES  REGIAO CENTRO-OESTE       GO        52001                  Central
# 2     AES  REGIAO CENTRO-OESTE       GO        52002               Centro Sul
# 3     AES  REGIAO CENTRO-OESTE       GO        52003            Entorno Norte
# 4     AES  REGIAO CENTRO-OESTE       GO        52004              Entorno Sul
# ..    ...                  ...      ...          ...                      ...
# 895   APS           REGIAO SUL       SC        42013        Serra Catarinense
# 896   APS           REGIAO SUL       SC        42014  Extremo Sul Catarinense
# 897   APS           REGIAO SUL       SC        42015              Carbonífera
# 898   APS           REGIAO SUL       SC        42016                   Laguna
# 899   APS           REGIAO SUL       SC        42017          Vale do Itapocu
#
# ...

# %% [markdown]
# ### 4.3.3. Resultado a nível UF
#
# Vamos gerar tabelas por unidade da federação e região.

# %%
resultado_uf = cd_oferta_vs_demanda_br.groupby(['nivel','regiao_pad','uf_sigla'], as_index= False).agg(necessidade=('necessidade','sum'),necessidade_sus=('necessidade_sus','sum'),oferta=('FTE_40_linha','sum'))

resultado_uf['ra'] = resultado_uf['oferta']- resultado_uf['necessidade'].round(2)
resultado_uf['rr'] = (resultado_uf['oferta']/resultado_uf['necessidade']* 100).round(2)
resultado_uf['ra_s'] = resultado_uf['oferta']- resultado_uf['necessidade_sus'].round(2)
resultado_uf['rr_s'] = (resultado_uf['oferta']/resultado_uf['necessidade_sus']*100).round(2)

resultado_uf['rr'] = np.where(resultado_uf['rr'] == 0.00, 0.01, resultado_uf['rr'])
resultado_uf['rr_s'] = np.where(resultado_uf['rr_s'] == 0.00, 0.01, resultado_uf['rr_s'])

resultado_uf.head()
# Out:
#   nivel           regiao_pad uf_sigla  necessidade  necessidade_sus  oferta  \
# 0   AES  REGIAO CENTRO-OESTE       DF       772.37           516.97   16.16
# 1   AES  REGIAO CENTRO-OESTE       GO      2298.74          1997.35  114.39
# 2   AES  REGIAO CENTRO-OESTE       MS       898.64           831.29   43.86
# 3   AES  REGIAO CENTRO-OESTE       MT      1106.32          1012.60   34.72
# 4   AES      REGIAO NORDESTE       AL      1118.60           984.25   49.76
#
#         ra    rr     ra_s  rr_s
# 0  -756.21  2.09  -500.81  3.13
# 1 -2184.35  4.98 -1882.96  5.73
# 2  -854.78  4.88  -787.43  5.28
# 3 -1071.60  3.14  -977.88  3.43
# 4 -1068.84  4.45  -934.49  5.06

# %% [markdown]
# ### 4.3.4. Resultado a nível Brasil

# %%
resultados_br = cd_oferta_vs_demanda_br.groupby(['nivel'], as_index= False).agg(necessidade=('necessidade','sum'),necessidade_sus=('necessidade_sus','sum'),oferta=('FTE_40_linha','sum'))

resultados_br['ra'] = resultados_br['oferta']- resultados_br['necessidade'].round(2)
resultados_br['rr'] = (resultados_br['oferta']/resultados_br['necessidade']*100).round(2)
resultados_br['ra_s'] = resultados_br['oferta']- resultados_br['necessidade_sus'].round(2)
resultados_br['rr_s'] = (resultados_br['oferta']/resultados_br['necessidade_sus']*100).round(2)

resultados_br['rr'] = np.where(resultados_br['rr'] == 0.00, 0.01, resultados_br['rr'])
resultados_br['rr_s'] = np.where(resultados_br['rr_s'] == 0.00, 0.01, resultados_br['rr_s'])

resultados_br
# Out:
#   nivel  necessidade  necessidade_sus   oferta         ra    rr       ra_s  \
# 0   AES     64149.28         53718.99  2545.27  -61604.01  3.97  -51173.72
# 1   APS    238478.75        201403.03  9429.54 -229049.21  3.95 -191973.49
#
#    rr_s
# 0  4.74
# 1  4.68

# %% [markdown]
# ### 4.4. Implicações de resultados em termos financeiros
#
# Ao final, sugere-se o cálculo do impacto financeiro desta lacuna. Isso pode ser feito multiplicando o RA ao salário médio de cirurgiões dentistas em Palmas-TO adicionado a um custo trabalhista.
#
# De acordo com dados da Pesquisa Nacional de Amostragem por Domicílio contínua (PNADc) do Instituto Brasileiro de Geografia e Estatística (IBGE), o salário médio é na ordem de R$ 4000. Adicionado a um fator para adicionar o custo trabalhista (1.42), tem-se os resultados na tabela a seguir.

# %%
#Rever sobre esse codigo 

#custo_palmas = cd_oferta_vs_demanda_br
#custo_palmas['custo_mensal'] = cd_oferta_vs_demanda_br['ra'] * (-1) * (4000 * 1.42)
#custo_palmas = custo_palmas[['ibge', 'municipio', 'nivel', 'CATEGORIA','custo_mensal']]
  
#custo_palmas

# %% [markdown]
# ## 5. Análise de Cenário
# ---
# Uma das últimas etapas do desenvolvimento de metodologias consiste na análise de cenário. Esta etapa é realizada, pois nem sempre temos parâmetros certos. Portanto, a análise é usada para simular a metodologia com diferentes parâmetros.
#
# Criamos uma função para iterar sobre alguns valores. Isso permitirá visualizar o impacto da mudança neles.

# %%
#Como na função existe uma variavel pd, é preciso importar o pandas novamente sem a sua abreviação para que não exista erro de identificação durante o carregamento

import pandas

# Criando a função
def gap_necessidade_oferta(tempo_aps,tempo_endo,tempo_prot,tempo_peri,ttd,pd,pl,sus,categoria,plano):
    pop_brasil['cod_municipiodv'] = pop_brasil['cod_municipiodv'].astype(str)
    pop_brasil['uf'] = pop_brasil['cod_municipiodv'].str.slice(0, 2)
    pop_brasil_tratado = pop_brasil[['cod_municipiodv','ibge_sb','municipio', 'de_0_a_14_anos','de_15_a_29_anos', 'de_30_a_59_anos','acima_de_60_anos']]
    pop_brasil_tratado = pandas.melt(pop_brasil_tratado, id_vars=['cod_municipiodv','ibge_sb', 'municipio'], var_name='faixa', value_name='total')
    
    pop_brasil_tratado['faixa'] = pop_brasil_tratado['faixa'].replace('_',' ', regex= True)
    pop_brasil_tratado['ibge_sb'] = pop_brasil_tratado['ibge_sb'].astype(str)
    pop_brasil_tratado['ibge'] = pop_brasil_tratado['ibge_sb'].str.slice(0,6)
    pop_brasil_tratado['cod_municipiodv'] = pop_brasil_tratado['cod_municipiodv'].astype(str)
    pop_brasil_tratado['cod_mun_loc'] = pop_brasil_tratado['cod_municipiodv']
    pop_brasil_tratado['cod_municipiodv'] = pop_brasil_tratado['cod_municipiodv'].str.slice(0,6)
    pop_brasil_tratado['id_faixa'] = np.where(pop_brasil_tratado['faixa'] == 'de 0 a 14 anos', 1,
                              np.where(pop_brasil_tratado['faixa'] == 'de 15 a 29 anos', 2,
                                       np.where(pop_brasil_tratado['faixa'] == 'de 30 a 59 anos',3,
                                                 np.where(pop_brasil_tratado['faixa'] == 'acima de 60 anos', 4, 0))))

    
    pop_brasil_tratado['ibge_sb'] = pop_brasil_tratado['ibge_sb'].astype(str)
    pop_brasil_tratado['ibge_sb'] = pop_brasil_tratado['ibge_sb'].str[:6]
    populacao_tratado = pandas.merge(pop_brasil_tratado,relacao_municipio_rs, how='left', left_on=['cod_municipiodv'], right_on = ['cod_municipio']) 
    populacao_tratado = pandas.merge(populacao_tratado,plano_odontologico_rs, how='left', on=['cod_regsaud', 'id_faixa']) 
    populacao_tratado = populacao_tratado.drop(columns=['benef','pop'])
    populacao_tratado['pop_sus'] = populacao_tratado['total']*(1 - populacao_tratado['cobertura_plano'])
    populacao_tratado = populacao_tratado.rename(columns={'id_faixa_x': 'id_faixa'})
    populacao_tratado = populacao_tratado.rename(columns={'cod_regsaud_x': 'cod_regsaud'})
 
    cobertura_sb['ibge'] = cobertura_sb['ibge'].astype(str)

    pop_coberta_br = pandas.merge(populacao_tratado, cobertura_sb, how='left', left_on=['ibge_sb','id_faixa'],right_on=['ibge','id_faixa'])
    pop_coberta_br = pop_coberta_br[['ibge_x', 'ibge_sb', 'municipio_x', 'faixa','id_faixa', 'total', 'procedimento', 'cobertura', 'cobertura_plano', 'pop_sus', 'cod_municipiodv', 'cod_mun_loc']]
    pop_coberta_br = pop_coberta_br.rename(columns={'municipio_x': 'municipio'})
    pop_coberta_br = pop_coberta_br.rename(columns={'ibge_x': 'ibge'})
    pop_coberta_br = pop_coberta_br.rename(columns={'cobertura': 'cobertura_servicos'})
    pop_coberta_br['populacao_coberta'] = (pop_coberta_br['cobertura_servicos'] * pop_coberta_br['total']).round(2)
    pop_coberta_br['populacao_coberta_sus'] = (pop_coberta_br['cobertura_servicos'] * pop_coberta_br['pop_sus']).round(2)

    producao_brasil = producao_normativa_br.drop(columns=['municipio','li_cobertura','ls_cobertura','faixa_etaria']) 
    necessidades_servicos_br = pandas.merge(pop_coberta_br,producao_brasil, how='left', left_on=['ibge','id_faixa','procedimento'],right_on=['ibge','id_faixa','procedimento'])
    necessidades_servicos_br['nec_servicos'] = necessidades_servicos_br['populacao_coberta']*necessidades_servicos_br['producao_pc'].round(2)
    necessidades_servicos_br['nec_servicos_sus'] = necessidades_servicos_br['populacao_coberta_sus']*necessidades_servicos_br['producao_pc'].round(2)
   
    necessidades_prof_br = necessidades_servicos_br.copy()

    necessidades_prof_br['nec_prof'] = necessidades_prof_br.apply(
    lambda row: (row['nec_servicos'] * (tempo_aps/60))/ttd if row['procedimento'] in ['Atenção Básica'] else
                (row['nec_servicos'] * (tempo_endo/60))/ttd if row['procedimento'] in ['Endodontia'] else
                (row['nec_servicos'] * (tempo_peri/60))/ttd if row['procedimento'] in ['Periodontia'] else
                (row['nec_servicos'] * (tempo_prot/60))/ttd if row['procedimento'] in ['Prótese'] else None,
    axis=1)

    necessidades_prof_br['nec_prof_sus'] = necessidades_prof_br.apply(
    lambda row: (row['nec_servicos_sus'] * (tempo_aps/60))/ttd if row['procedimento'] in ['Atenção Básica'] else
                (row['nec_servicos_sus'] * (tempo_endo/60))/ttd if row['procedimento'] in ['Endodontia'] else
                (row['nec_servicos_sus'] * (tempo_peri/60))/ttd if row['procedimento'] in ['Periodontia'] else
                (row['nec_servicos_sus'] * (tempo_prot/60))/ttd if row['procedimento'] in ['Prótese'] else None,
    axis=1)

    necessidades_prof_br['nivel'] = np.where(necessidades_prof_br['procedimento'] == 'Atenção Básica', 'APS', 'AES')
    necessidades_prof_br = necessidades_prof_br.groupby(['ibge', 'municipio', 'nivel', 'cod_municipiodv', 'cod_mun_loc'], as_index= False).agg(necessidade=('nec_prof', 'sum'),necessidade_sus=('nec_prof_sus', 'sum')).round(2) 

    oferta_prof = oferta_brasil[oferta_brasil['profissional'] == categoria]
    
    todos = True  

    if todos == sus:
        oferta_temp = oferta_prof[oferta_prof ['SUS']=='1'].copy()
    else:
        oferta_temp = oferta_prof.groupby(['ibge','profissional', 'nivel'], as_index=False).agg({'fte40':'sum'})

    oferta_temp['fte40'] = oferta_temp['fte40'].fillna(0)

    oferta_temp['FTE_40_direto'] = oferta_temp['fte40']*pd
    oferta_temp['FTE_40_linha'] = oferta_temp['FTE_40_direto']*pl
 
    oferta_temp[['FTE_40_direto', 'FTE_40_linha']] = oferta_temp[['FTE_40_direto', 'FTE_40_linha']].fillna(0)

    flag = 1 


    flag = plano

    oferta_vs_demanda = pandas.merge(necessidades_prof_br, oferta_temp, how = 'left', left_on = ['cod_municipiodv','nivel'], right_on = ['ibge','nivel'])
    oferta_vs_demanda = pandas.merge(oferta_vs_demanda, hierarquia_municipios, how = 'left', left_on = ['cod_municipiodv'], right_on = ['cod_municipio'])
    oferta_vs_demanda['ra'] = np.where(flag == 1, oferta_vs_demanda['FTE_40_linha']- oferta_vs_demanda['necessidade'],
                                       oferta_vs_demanda['FTE_40_linha']- oferta_vs_demanda['necessidade_sus'])
    oferta_vs_demanda['rr'] = np.where(flag == 1, oferta_vs_demanda['FTE_40_linha']/oferta_vs_demanda['necessidade'],
                                       oferta_vs_demanda['FTE_40_linha']/oferta_vs_demanda['necessidade_sus'])
    
    oferta_vs_demanda['ra'] = oferta_vs_demanda['ra'].round(2)
    oferta_vs_demanda['rr'] = oferta_vs_demanda['rr'].round(2)
    oferta_vs_demanda['necessidade'] = oferta_vs_demanda['necessidade'].round(2)
    oferta_vs_demanda['FTE_40_linha'] = oferta_vs_demanda['FTE_40_linha'].round(2)

### falta colocar as flags aqui para pegar a população SUS dependente 

    cd_oferta_vs_demanda_regiao_saude = oferta_vs_demanda.groupby(['nivel','cod_regsaud','uf_sigla','regiao_saude'], as_index=False).agg(necessidade = ('necessidade', 'sum'),necessidade_sus = ('necessidade_sus', 'sum'),oferta = ('FTE_40_linha', 'sum'))
    cd_oferta_vs_demanda_regiao_saude['ra'] = np.where(flag == 1, cd_oferta_vs_demanda_regiao_saude['oferta']- cd_oferta_vs_demanda_regiao_saude['necessidade'],
                                       cd_oferta_vs_demanda_regiao_saude['oferta']- cd_oferta_vs_demanda_regiao_saude['necessidade_sus'])
    cd_oferta_vs_demanda_regiao_saude['rr'] = np.where(flag == 1, cd_oferta_vs_demanda_regiao_saude['oferta']/cd_oferta_vs_demanda_regiao_saude['necessidade'],
                                       cd_oferta_vs_demanda_regiao_saude['oferta']/cd_oferta_vs_demanda_regiao_saude['necessidade_sus'])
    
    cd_oferta_vs_demanda_regiao_saude['ra'] = (cd_oferta_vs_demanda_regiao_saude['ra'] * 100).round(2)
    cd_oferta_vs_demanda_regiao_saude['rr'] = (cd_oferta_vs_demanda_regiao_saude['rr'] * 100).round(2)
    cd_oferta_vs_demanda_regiao_saude['rr'] = np.where(cd_oferta_vs_demanda_regiao_saude['rr'] == 0.00, 0.01, cd_oferta_vs_demanda_regiao_saude['rr'])


    return cd_oferta_vs_demanda_regiao_saude

# %% [markdown]
# ### 5.1. Quatro cenários do estudo
#
# Nesta seção vamos aplicar os quatro cenários que foram sugeridos nesta pesquisa.

# %%
baseline = gap_necessidade_oferta( tempo_aps = 45,
                                   tempo_endo = 45,
                                   tempo_prot = 55,
                                   tempo_peri = 55,
                                   pd = 0.4,   
                                   pl = 0.5, 
                                   ttd = 1576, 
                                   sus = True,
                                   categoria = '2232',  
                                   plano = 1)
baseline['cenario'] = 'baseline'

# %%
baseline
# Out:
#     nivel  cod_regsaud uf_sigla      regiao_saude  necessidade  \
# 0     AES        11001       RO    Vale do Jamari        85.73
# 1     AES        11002       RO              Café        69.10
# 2     AES        11003       RO           Central       136.32
# 3     AES        11004       RO    Madeira-Mamoré       162.48
# 4     AES        11005       RO      Zona da Mata        53.66
# ..    ...          ...      ...               ...          ...
# 895   APS        52015       GO        Sudoeste I       646.89
# 896   APS        52016       GO       Sudoeste II       347.28
# 897   APS        52017       GO               Sul       375.39
# 898   APS        52018       GO   São Patrício II       262.66
# 899   APS        53001       DF  Distrito Federal      2492.34
#
#      necessidade_sus  oferta        ra    rr   cenario
# 0              81.63    1.00   -8473.0  1.17  baseline
# 1              64.50    2.00   -6710.0  2.89  baseline
# ...

# %%
cenario2 = gap_necessidade_oferta(tempo_aps = 25,  
                                   tempo_endo = 35,  
                                   tempo_prot = 35, 
                                   tempo_peri = 35, 
                                   pd = 0.6,       
                                   pl = 0.6,     
                                   ttd = 1676,      
                                   sus = True, 
                                   categoria = '2232',   
                                   plano = 1)  
cenario2['cenario'] = 'cenario 2'

# %%
cenario2
# Out:
#     nivel  cod_regsaud uf_sigla      regiao_saude  necessidade  \
# 0     AES        11001       RO    Vale do Jamari        51.65
# 1     AES        11002       RO              Café        41.63
# 2     AES        11003       RO           Central        82.09
# 3     AES        11004       RO    Madeira-Mamoré        97.53
# 4     AES        11005       RO      Zona da Mata        32.29
# ..    ...          ...      ...               ...          ...
# 895   APS        52015       GO        Sudoeste I       337.94
# 896   APS        52016       GO       Sudoeste II       181.44
# 897   APS        52017       GO               Sul       196.10
# 898   APS        52018       GO   São Patrício II       137.22
# 899   APS        53001       DF  Distrito Federal      1302.02
#
#      necessidade_sus  oferta        ra     rr    cenario
# 0              49.19    1.80   -4985.0   3.48  cenario 2
# 1              38.86    3.60   -3803.0   8.65  cenario 2
# ...

# %%
cenario3 = gap_necessidade_oferta(tempo_aps = 25,
                                   tempo_endo = 35,   
                                   tempo_prot = 35, 
                                   tempo_peri = 35, 
                                   pd = 0.6,        
                                   pl = 0.6,    
                                   ttd = 1676,   
                                   sus = True,  
                                   categoria = '2232', 
                                   plano = 0) 
cenario3['cenario'] = 'cenario 3'

# %%
cenario3
# Out:
#     nivel  cod_regsaud uf_sigla      regiao_saude  necessidade  \
# 0     AES        11001       RO    Vale do Jamari        54.93
# 1     AES        11002       RO              Café        44.26
# 2     AES        11003       RO           Central        87.31
# 3     AES        11004       RO    Madeira-Mamoré       103.72
# 4     AES        11005       RO      Zona da Mata        34.37
# ..    ...          ...      ...               ...          ...
# 895   APS        52015       GO        Sudoeste I       359.40
# 896   APS        52016       GO       Sudoeste II       192.94
# 897   APS        52017       GO               Sul       208.55
# 898   APS        52018       GO   São Patrício II       145.93
# 899   APS        53001       DF  Distrito Federal      1384.63
#
#      necessidade_sus  oferta       ra     rr    cenario
# 0              52.32    1.80  -5052.0   3.44  cenario 3
# 1              41.31    3.60  -3771.0   8.71  cenario 3
# ...

# %%
cenario4 = gap_necessidade_oferta(tempo_aps = 25,
                                   tempo_endo = 35,   
                                   tempo_prot = 35, 
                                   tempo_peri = 35, 
                                   pd = 0.6,        
                                   pl = 0.6,    
                                   ttd = 1676,   
                                   sus = False,  
                                   categoria = '2232', 
                                   plano = 0)  

cenario4['cenario'] = 'cenario 4'

# %%
cenario4
# Out:
#     nivel  cod_regsaud uf_sigla      regiao_saude  necessidade  \
# 0     AES        11001       RO    Vale do Jamari        54.93
# 1     AES        11002       RO              Café        44.26
# 2     AES        11003       RO           Central        87.31
# 3     AES        11004       RO    Madeira-Mamoré       103.72
# 4     AES        11005       RO      Zona da Mata        34.37
# ..    ...          ...      ...               ...          ...
# 895   APS        52015       GO        Sudoeste I       359.40
# 896   APS        52016       GO       Sudoeste II       192.94
# 897   APS        52017       GO               Sul       208.55
# 898   APS        52018       GO   São Patrício II       145.93
# 899   APS        53001       DF  Distrito Federal      1384.63
#
#      necessidade_sus  oferta       ra      rr    cenario
# 0              52.32   16.74  -3558.0   32.00  cenario 4
# 1              41.31   79.98   3867.0  193.61  cenario 4
# ...

# %% [markdown]
# ### 5.2. Executando a função para um conjunto de valores
#
# Utilizamos uma lista de valores para iterar conforme a tabela abaixo. Estas combinações resultaram em 1600 combinações de resultados.
#
# ---
# **Parâmetro** |    *Sigla* |   Valores
#
# ---
# **Tempo total disponível:**|	*TTD*	| em horas: 1576; 1676; 1776; 1876
#
# ---
# **Tempo de procedimentos:**|	*T*	| em minutos: 25, 35, 45, 55
#
# ---
# **Percentual de atividades diretas:**|	*PD*	| em unidade percentual: 50%, 60%, 80%, 90%, 100%
#
# ---
# **Percentual de atividades da linha de cuidado:**|	*PL*	| em unidade percentual: 50%, 60%, 80%, 90%, 100%
#
# ---
# **Categoria profissional:**|	*CAT*	| Cirurgião-dentista e Técnico/Auxiliar de Saúde Bucal
#
# ---
# **Recorte de Profissionais:**|	*SUS*	| TRUE (pegar todos profissionais, SUS e não SUS) ou FALSE (pegar só os profissionais SUS)
#
# ---

# %%
#Criando uma nova função para retornar uma tabela com mais variaveis 
import pandas

# Criando a função
def gap_necessidade_oferta_2(tempo_aps,tempo_endo,tempo_prot,tempo_peri,ttd,pd,pl,sus,categoria,plano):
    pop_brasil['cod_municipiodv'] = pop_brasil['cod_municipiodv'].astype(str)
    pop_brasil['uf'] = pop_brasil['cod_municipiodv'].str.slice(0, 2)
    pop_brasil_tratado = pop_brasil[['cod_municipiodv','ibge_sb','municipio', 'de_0_a_14_anos','de_15_a_29_anos', 'de_30_a_59_anos','acima_de_60_anos']]
    pop_brasil_tratado = pandas.melt(pop_brasil_tratado, id_vars=['cod_municipiodv','ibge_sb', 'municipio'], var_name='faixa', value_name='total')
    
    pop_brasil_tratado['faixa'] = pop_brasil_tratado['faixa'].replace('_',' ', regex= True)
    pop_brasil_tratado['ibge_sb'] = pop_brasil_tratado['ibge_sb'].astype(str)
    pop_brasil_tratado['ibge'] = pop_brasil_tratado['ibge_sb'].str.slice(0,6)
    pop_brasil_tratado['cod_municipiodv'] = pop_brasil_tratado['cod_municipiodv'].astype(str)
    pop_brasil_tratado['cod_mun_loc'] = pop_brasil_tratado['cod_municipiodv']
    pop_brasil_tratado['cod_municipiodv'] = pop_brasil_tratado['cod_municipiodv'].str.slice(0,6)
    pop_brasil_tratado['id_faixa'] = np.where(pop_brasil_tratado['faixa'] == 'de 0 a 14 anos', 1,
                              np.where(pop_brasil_tratado['faixa'] == 'de 15 a 29 anos', 2,
                                       np.where(pop_brasil_tratado['faixa'] == 'de 30 a 59 anos',3,
                                                 np.where(pop_brasil_tratado['faixa'] == 'acima de 60 anos', 4, 0))))

    
    pop_brasil_tratado['ibge_sb'] = pop_brasil_tratado['ibge_sb'].astype(str)
    pop_brasil_tratado['ibge_sb'] = pop_brasil_tratado['ibge_sb'].str[:6]
    populacao_tratado = pandas.merge(pop_brasil_tratado,relacao_municipio_rs, how='left', left_on=['cod_municipiodv'], right_on = ['cod_municipio']) 
    populacao_tratado = pandas.merge(populacao_tratado,plano_odontologico_rs, how='left', on=['cod_regsaud', 'id_faixa']) 
    populacao_tratado = populacao_tratado.drop(columns=['benef','pop'])
    populacao_tratado['pop_sus'] = populacao_tratado['total']*(1 - populacao_tratado['cobertura_plano'])
    populacao_tratado = populacao_tratado.rename(columns={'id_faixa_x': 'id_faixa'})
    populacao_tratado = populacao_tratado.rename(columns={'cod_regsaud_x': 'cod_regsaud'})
 
    cobertura_sb['ibge'] = cobertura_sb['ibge'].astype(str)

    pop_coberta_br = pandas.merge(populacao_tratado, cobertura_sb, how='left', left_on=['ibge_sb','id_faixa'],right_on=['ibge','id_faixa'])
    pop_coberta_br = pop_coberta_br[['ibge_x', 'ibge_sb', 'municipio_x', 'faixa','id_faixa', 'total', 'procedimento', 'cobertura', 'cobertura_plano', 'pop_sus', 'cod_municipiodv', 'cod_mun_loc']]
    pop_coberta_br = pop_coberta_br.rename(columns={'municipio_x': 'municipio'})
    pop_coberta_br = pop_coberta_br.rename(columns={'ibge_x': 'ibge'})
    pop_coberta_br = pop_coberta_br.rename(columns={'cobertura': 'cobertura_servicos'})
    pop_coberta_br['populacao_coberta'] = (pop_coberta_br['cobertura_servicos'] * pop_coberta_br['total']).round(2)
    pop_coberta_br['populacao_coberta_sus'] = (pop_coberta_br['cobertura_servicos'] * pop_coberta_br['pop_sus']).round(2)

    producao_brasil = producao_normativa_br.drop(columns=['municipio','li_cobertura','ls_cobertura','faixa_etaria']) 
    necessidades_servicos_br = pandas.merge(pop_coberta_br,producao_brasil, how='left', left_on=['ibge','id_faixa','procedimento'],right_on=['ibge','id_faixa','procedimento'])
    necessidades_servicos_br['nec_servicos'] = necessidades_servicos_br['populacao_coberta']*necessidades_servicos_br['producao_pc'].round(2)
    necessidades_servicos_br['nec_servicos_sus'] = necessidades_servicos_br['populacao_coberta_sus']*necessidades_servicos_br['producao_pc'].round(2)
   
    necessidades_prof_br = necessidades_servicos_br.copy()

    necessidades_prof_br['nec_prof'] = necessidades_prof_br.apply(
    lambda row: (row['nec_servicos'] * (tempo_aps/60)) / ttd if row['procedimento'] in ['Atenção Básica'] else
                (row['nec_servicos'] * (tempo_endo/60)) / ttd if row['procedimento'] in ['Endodontia'] else
                (row['nec_servicos'] * (tempo_peri/60)) / ttd if row['procedimento'] in ['Periodontia'] else
                (row['nec_servicos'] * (tempo_prot/60)) / ttd if row['procedimento'] in ['Prótese'] else None,
    axis=1)

    necessidades_prof_br['nec_prof_sus'] = necessidades_prof_br.apply(
    lambda row: (row['nec_servicos_sus'] * (tempo_aps/60)) / ttd if row['procedimento'] in ['Atenção Básica'] else
                (row['nec_servicos_sus'] * (tempo_endo/60)) / ttd if row['procedimento'] in ['Endodontia'] else
                (row['nec_servicos_sus'] * (tempo_peri/60)) / ttd if row['procedimento'] in ['Periodontia'] else
                (row['nec_servicos_sus'] * (tempo_prot/60)) / ttd if row['procedimento'] in ['Prótese'] else None,
    axis=1)

    necessidades_prof_br['nivel'] = np.where(necessidades_prof_br['procedimento'] == 'Atenção Básica', 'APS', 'AES')
    necessidades_prof_br = necessidades_prof_br.groupby(['ibge', 'municipio', 'nivel', 'cod_municipiodv', 'cod_mun_loc'], as_index= False).agg(necessidade=('nec_prof', 'sum'),necessidade_sus=('nec_prof_sus', 'sum')).round(2) 

    oferta_prof = oferta_brasil[oferta_brasil['profissional'] == categoria]
    
    todos = True  

    if todos == sus:
        oferta_temp = oferta_prof[oferta_prof ['SUS']=='1'].copy()
    else:
        oferta_temp = oferta_prof.groupby(['ibge','profissional', 'nivel'], as_index=False).agg({'fte40':'sum'})

    oferta_temp['fte40'] = oferta_temp['fte40'].fillna(0)

    oferta_temp['FTE_40_direto'] = oferta_temp['fte40']*pd
    oferta_temp['FTE_40_linha'] = oferta_temp['FTE_40_direto']*pl
 
    oferta_temp[['FTE_40_direto', 'FTE_40_linha']] = oferta_temp[['FTE_40_direto', 'FTE_40_linha']].fillna(0)

    flag = 1 


    flag = plano

    oferta_vs_demanda = pandas.merge(necessidades_prof_br, oferta_temp, how = 'left', left_on = ['cod_municipiodv','nivel'], right_on = ['ibge','nivel'])
    oferta_vs_demanda = pandas.merge(oferta_vs_demanda, hierarquia_municipios, how = 'left', left_on = ['cod_municipiodv'], right_on = ['cod_municipio'])
    oferta_vs_demanda['ra'] = np.where(flag == 1, oferta_vs_demanda['FTE_40_linha']- oferta_vs_demanda['necessidade'],
                                       oferta_vs_demanda['FTE_40_linha']- oferta_vs_demanda['necessidade_sus'])
    oferta_vs_demanda['rr'] = np.where(flag == 1, oferta_vs_demanda['FTE_40_linha']/oferta_vs_demanda['necessidade'],
                                       oferta_vs_demanda['FTE_40_linha']/oferta_vs_demanda['necessidade_sus'])
    
    oferta_vs_demanda['ra'] = oferta_vs_demanda['ra'].round(2)
    oferta_vs_demanda['rr'] = oferta_vs_demanda['rr'].round(2)
    oferta_vs_demanda['necessidade'] = oferta_vs_demanda['necessidade'].round(2)
    oferta_vs_demanda['FTE_40_linha'] = oferta_vs_demanda['FTE_40_linha'].round(2)

### falta colocar as flags aqui para pegar a população SUS dependente 

    cd_oferta_vs_demanda_regiao_saude = oferta_vs_demanda.groupby(['nivel','cod_regsaud','uf_sigla','regiao_saude'],as_index=False).agg(necessidade = ('necessidade', 'sum'),necessidade_sus = ('necessidade_sus', 'sum'),oferta = ('FTE_40_linha', 'sum'))
    cd_oferta_vs_demanda_regiao_saude['ra'] = np.where(flag == 1, cd_oferta_vs_demanda_regiao_saude['oferta']- cd_oferta_vs_demanda_regiao_saude['necessidade'],
                                       cd_oferta_vs_demanda_regiao_saude['oferta']- cd_oferta_vs_demanda_regiao_saude['necessidade_sus'])
    cd_oferta_vs_demanda_regiao_saude['rr'] = np.where(flag == 1, cd_oferta_vs_demanda_regiao_saude['oferta']/cd_oferta_vs_demanda_regiao_saude['necessidade'],
                                       cd_oferta_vs_demanda_regiao_saude['oferta']/cd_oferta_vs_demanda_regiao_saude['necessidade_sus'])
    
    cd_oferta_vs_demanda_regiao_saude['ra'] = (cd_oferta_vs_demanda_regiao_saude['ra'] * 100).round(2)
    cd_oferta_vs_demanda_regiao_saude['rr'] = (cd_oferta_vs_demanda_regiao_saude['rr'] * 100).round(2)
    cd_oferta_vs_demanda_regiao_saude['rr'] = np.where(cd_oferta_vs_demanda_regiao_saude['rr'] == 0.00, 0.01, cd_oferta_vs_demanda_regiao_saude['rr'])

    oferta_vs_demanda2 = oferta_vs_demanda.copy()
    oferta_vs_demanda2 = oferta_vs_demanda2.drop(columns=['ibge_y','cod_municipiodv_y','municipio_y','necessidade','necessidade_sus','ra','rr'])
    oferta_vs_demanda2= oferta_vs_demanda2.rename(columns = {'ibge_x':'ibge','cod_municipiodv_x':'cod_municipiodv','municipio_x':'municipio'})
    

    cd_oferta_vs_demanda_regiao_saude_2 = oferta_vs_demanda2.merge(cd_oferta_vs_demanda_regiao_saude, how='left', on=['nivel', 'cod_regsaud', 'uf_sigla', 'regiao_saude'])

    
    return cd_oferta_vs_demanda_regiao_saude_2

# %%
list_ttd = [1576, 1876]
list_tempo_aps = [25, 75]
list_tempo_endo = [25, 35]
list_tempo_prot = [45, 55]
list_tempo_peri = [65, 75]
list_pd = [0.50, 0.90, 1]
list_pl = [0.50, 0.60]
list_cat = ['2232']  #,'3224']
list_sus = [True, False]
list_plano = [0, 1]

resultado1 = []
iteracao1 = 0
total_iteracoes1 = (len(list_ttd) * len(list_tempo_aps) * len(list_tempo_endo) *
  len(list_tempo_prot) * len(list_tempo_peri) * len(list_pd) *
  len(list_pl) * len(list_cat) * len(list_sus) * len(list_plano))

for ttd in list_ttd:
    for tempo_aps in list_tempo_aps:
        for tempo_endo in list_tempo_endo:
            for tempo_prot in list_tempo_prot:
                for tempo_peri in list_tempo_peri:
                    for pd in list_pd:
                        for pl in list_pl:
                            for sus in list_sus:
                                for categoria in list_cat:
                                    for plano in list_plano:

                                        iteracao1 = iteracao1 + 1
                                        print(f"Iteração: {iteracao1} de {total_iteracoes1}")

                                        res1 = gap_necessidade_oferta_2(
                                            tempo_aps=tempo_aps,
                                            tempo_endo=tempo_endo,
                                            tempo_prot=tempo_prot,
                                            tempo_peri=tempo_peri,
                                            ttd=ttd,
                                            pd=pd,
                                            pl=pl,
                                            sus=sus,
                                            categoria=categoria,
                                            plano=plano
                                        )

                                        res1 = res1.assign(
                                            ttd=ttd, tempo_aps=tempo_aps, tempo_endo=tempo_endo, 
                                            tempo_prot=tempo_prot, tempo_peri=tempo_peri, 
                                            pd=pd, pl=pl, sus=sus, categoria=categoria, plano=plano
                                        )

                                        res1['atributos'] = res1.apply(
                                            lambda row: f"{ttd}_{tempo_aps}_{tempo_endo}_{tempo_prot}_{tempo_peri}_{pd}_{pl}_{sus}_{categoria}_{plano}", 
                                            axis=1
                                        )
                                        resultado1.append(res1)



#len(resultado1)

resultado_teste1 = pandas.concat(resultado1, ignore_index=True, copy=False)
# Out:
# Iteração: 1 de 768
# Iteração: 2 de 768
# Iteração: 3 de 768
# Iteração: 4 de 768
# Iteração: 5 de 768
# Iteração: 6 de 768
# Iteração: 7 de 768
# Iteração: 8 de 768
# Iteração: 9 de 768
# Iteração: 10 de 768
# Iteração: 11 de 768
# Iteração: 12 de 768
# Iteração: 13 de 768
# Iteração: 14 de 768
# Iteração: 15 de 768
# Iteração: 16 de 768
# Iteração: 17 de 768
# Iteração: 18 de 768
# Iteração: 19 de 768
# Iteração: 20 de 768
# Iteração: 21 de 768
# Iteração: 22 de 768
# Iteração: 23 de 768
# Iteração: 24 de 768
# Iteração: 25 de 768
# Iteração: 26 de 768
# Iteração: 27 de 768
# Iteração: 28 de 768
# Iteração: 29 de 768
# Iteração: 30 de 768
# Iteração: 31 de 768
# Iteração: 32 de 768
# Iteração: 33 de 768
# Iteração: 34 de 768
# Iteração: 35 de 768
# Iteração: 36 de 768
# Iteração: 37 de 768
# Iteração: 38 de 768
# Iteração: 39 de 768
# Iteração: 40 de 768
# Iteração: 41 de 768
# Iteração: 42 de 768
# Iteração: 43 de 768
# Iteração: 44 de 768
# Iteração: 45 de 768
# ...

# %%
resultado = resultado_teste1
resultado['prof'] = np.where(resultado['categoria'] == '2232','Dentista','TSB/ASB')
resultado['sus'] = np.where(resultado['sus'] == True, 'Apenas SUS','Todos')
resultado = resultado[['cod_municipiodv', 'regiao', 'uf_sigla', 'uf', 'municipio',  'regiao_saude', 'cod_regsaud', 'nivel', 'profissional', 'categoria', 'sus', 'necessidade', 'fte40', 'FTE_40_direto','FTE_40_linha', 'ra', 'rr', 'ttd','tempo_aps', 'tempo_endo', 'tempo_prot', 'tempo_peri', 'pd', 'pl','plano','atributos']]

# %%
resultado
# Out:
#         cod_municipiodv               regiao uf_sigla                uf  \
# 0                110020         Região Norte       RO          Rondônia
# 1                110020         Região Norte       RO          Rondônia
# 2                120040         Região Norte       AC              Acre
# 3                120040         Região Norte       AC              Acre
# 4                150010         Região Norte       PA              Pará
# ...                 ...                  ...      ...               ...
# 8555515          520025  Região Centro-Oeste       GO             Goiás
# 8555516          520870  Região Centro-Oeste       GO             Goiás
# 8555517          520870  Região Centro-Oeste       GO             Goiás
# 8555518          530010  Região Centro-Oeste       DF  Distrito Federal
# 8555519          530010  Região Centro-Oeste       DF  Distrito Federal
#
#                      municipio        regiao_saude  cod_regsaud nivel  \
# ...

# %% [markdown]
# Estas iterações resultaram em 1600 combinações que levaram a construção de um dataframe com 17.824.000 observações (5570 municípios x 1600 combinações x cálculos de necessidades para 2 níveis de atenção). A apresentação destes resultados ocorrerá por meio de um dashboard.

# %% [markdown]
# # Referências
#
# Asamani, J. A., Christmals, C. D., & Reitsma, G. M. (2021). The needs-based health workforce planning method: a systematic scoping review of analytical applications. *Health Policy and Planning, 36(8)*, 1325-1343.
#
# Belotti, L., Maito, S., Vesga-Varela, A. L., de Almeida, L. Y., da Silva, M. T., Haddad, A. E., … & Bonfim, D. (2024). Activities of the oral health teams in primary health care: a time-motion study. *BMC Health Services Research, 24(1)*, 617.
#
# Brasil (2017). Portaria de Consolidação nº 1, 28 de setembro de 2017. *Consolidação das normas sobre os direitos e deveres dos usuários da saúde, a organização e o funcionamento do Sistema Único de Saúde. Diário Oficial da União.*
